# %%
import os 
from dotenv import load_dotenv, find_dotenv

# This function will load all the variables from the .env file and will 
# make them available in the os.environ dictionary (env variables)
load_dotenv(find_dotenv()) 

# Check for Google's API key instead of OpenAI's
if os.environ.get("GOOGLE_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("GOOGLE_API_KEY not found")

from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser, PydanticOutputParser

# Import the Google GenAI module
from langchain_google_genai import ChatGoogleGenerativeAI

# Initialize the Gemini model (using gemini-1.5-flash as an equivalent to a 'mini' model)
llm_gemini = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

# %%
import os 
from dotenv import load_dotenv, find_dotenv

# This function will load all the variables from the .env file and will 
# make them available in the os.environ dictionary (env variables)
load_dotenv(find_dotenv()) 

# Check for Google's API key instead of OpenAI's
if os.environ.get("GOOGLE_API_KEY"):
    print("Bro API KEY Variable exists")
else:
    raise ValueError("GOOGLE_API_KEY not found")

from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser, PydanticOutputParser

# Import the Google GenAI module
from langchain_google_genai import ChatGoogleGenerativeAI

# Initialize the Gemini model (using gemini-1.5-flash as an equivalent to a 'mini' model)
llm_gemini = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

# %%
## tool -01 [duck duckgo]
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun(description="This is a tool to search the web for news")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 ## tool -01 [duck duckgo]
# ----> 2 from langchain_community.tools import DuckDuckGoSearchRun
#       3
#       4 search_tool = DuckDuckGoSearchRun(description="This is a tool to search the web for news")
#
# ModuleNotFoundError: No module named 'langchain_community'
